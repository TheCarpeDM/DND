# %%
#  Import dependencies and read the csv.
import pandas as pd 
monsters_df = pd.read_csv("dnd_monsters.csv")
monsters_df.head()
# Out:
#               name                                                url   cr
# 0        aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  1/4  \
# 1          abjurer                                                NaN    9
# 2          aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...   10
# 3  abominable-yeti                                                NaN    9
# 4         acererak                                                NaN   23
#
#                    type    size  ac   hp speed          align  legendary
# 0  humanoid (aarakocra)  Medium  12   13   fly   neutral good        NaN  \
# 1   humanoid (any race)  Medium  12   84   NaN  any alignment        NaN
# 2            aberration   Large  17  135  swim    lawful evil  Legendary
# 3           monstrosity    Huge  15  137   NaN   chaotic evil        NaN
# 4                undead  Medium  21  285   NaN   neutral evil        NaN
#
#                               source   str   dex   con   int   wis   cha
# 0                Monster Manual (BR)  10.0  14.0  10.0  11.0  12.0  11.0
# 1           Volo's Guide to Monsters   NaN   NaN   NaN   NaN   NaN   NaN
# 2               Monster Manual (SRD)  21.0   9.0  15.0  18.0  15.0  18.0
# 3                     Monster Manual   NaN   NaN   NaN   NaN   NaN   NaN
# 4  Adventures (Tomb of Annihilation)   NaN   NaN   NaN   NaN   NaN   NaN

# %%
#Drop columns we don't need (align & source)
monsters_df = monsters_df.drop(columns=['align', 'source'])
monsters_df.head()
# Out:
#               name                                                url   cr
# 0        aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  1/4  \
# 1          abjurer                                                NaN    9
# 2          aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...   10
# 3  abominable-yeti                                                NaN    9
# 4         acererak                                                NaN   23
#
#                    type    size  ac   hp speed  legendary   str   dex   con
# 0  humanoid (aarakocra)  Medium  12   13   fly        NaN  10.0  14.0  10.0  \
# 1   humanoid (any race)  Medium  12   84   NaN        NaN   NaN   NaN   NaN
# 2            aberration   Large  17  135  swim  Legendary  21.0   9.0  15.0
# 3           monstrosity    Huge  15  137   NaN        NaN   NaN   NaN   NaN
# 4                undead  Medium  21  285   NaN        NaN   NaN   NaN   NaN
#
#     int   wis   cha
# 0  11.0  12.0  11.0
# 1   NaN   NaN   NaN
# 2  18.0  15.0  18.0
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN

# %%
#Drop Nan rows ONLY from str
monsters_df = monsters_df.dropna(subset=['str'])
monsters_df.head()
# Out:
#                  name                                                url   cr
# 0           aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  1/4  \
# 2             aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...   10
# 5             acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...  1/4
# 6  adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...   14
# 8   adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...   16
#
#                    type    size  ac   hp      speed  legendary   str   dex
# 0  humanoid (aarakocra)  Medium  12   13        fly        NaN  10.0  14.0  \
# 2            aberration   Large  17  135       swim  Legendary  21.0   9.0
# 5   humanoid (any race)  Medium  10    9        NaN        NaN  10.0  10.0
# 6                dragon    Huge  19  195  fly, swim  Legendary  23.0  14.0
# 8                dragon    Huge  19  225        fly  Legendary  25.0  10.0
#
#     con   int   wis   cha
# 0  10.0  11.0  12.0  11.0
# 2  15.0  18.0  15.0  18.0
# 5  10.0  10.0  14.0  11.0
# 6  21.0  14.0  13.0  17.0
# 8  23.0  16.0  15.0  19.0

# %%
#Check data types and changed any if needed
monsters_df.dtypes
# Out:
# name          object
# url           object
# cr            object
# type          object
# size          object
# ac             int64
# hp             int64
# speed         object
# legendary     object
# str          float64
# dex          float64
# con          float64
# int          float64
# wis          float64
# cha          float64
# dtype: object

# %%
#CR column should be float but we need to conver fractions
#take from: https://stackoverflow.com/questions/69112191/convert-fractional-values-to-decimal-in-pandas
def convert(frac):
    if '/' in frac:
        num, den = frac.split('/')
        return (int(num)/int(den))
    else:
        return float(frac)

monsters_df['cr'] = monsters_df['cr'].apply(convert)
monsters_df.head()
# Out:
#                  name                                                url
# 0           aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  \
# 2             aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 5             acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...
# 6  adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 8   adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
#
#       cr                  type    size  ac   hp      speed  legendary   str
# 0   0.25  humanoid (aarakocra)  Medium  12   13        fly        NaN  10.0  \
# 2  10.00            aberration   Large  17  135       swim  Legendary  21.0
# 5   0.25   humanoid (any race)  Medium  10    9        NaN        NaN  10.0
# 6  14.00                dragon    Huge  19  195  fly, swim  Legendary  23.0
# 8  16.00                dragon    Huge  19  225        fly  Legendary  25.0
#
#     dex   con   int   wis   cha
# 0  14.0  10.0  11.0  12.0  11.0
# 2   9.0  15.0  18.0  15.0  18.0
# 5  10.0  10.0  10.0  14.0  11.0
# 6  14.0  21.0  14.0  13.0  17.0
# 8  10.0  23.0  16.0  15.0  19.0

# %%
#Check dtypes and convert if needed
monsters_df.dtypes
# Out:
# name          object
# url           object
# cr           float64
# type          object
# size          object
# ac             int64
# hp             int64
# speed         object
# legendary     object
# str          float64
# dex          float64
# con          float64
# int          float64
# wis          float64
# cha          float64
# dtype: object

# %%
#Split speed column on ','
monsters_df[['fly', 'swim']] = monsters_df['speed'].str.split(',', expand=True)
monsters_df = monsters_df.drop(columns='speed')

monsters_df.head(10)
# Out:
#                    name                                                url
# 0             aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  \
# 2               aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 5               acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...
# 6    adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 8     adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 9    adult-brass-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 10  adult-bronze-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 11  adult-copper-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 12    adult-gold-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 13   adult-green-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
#
#        cr                  type    size  ac   hp  legendary   str   dex   con
# 0    0.25  humanoid (aarakocra)  Medium  12   13        NaN  10.0  14.0  10.0  \
# 2   10.00            aberration   Large  17  135  Legendary  21.0   9.0  15.0
# 5    0.25   humanoid (any race)  Medium  10    9        NaN  10.0  10.0  10.0
# 6   14.00                dragon    Huge  19  195  Legendary  23.0  14.0  21.0
# 8   16.00                dragon    Huge  19  225  Legendary  25.0  10.0  23.0
# 9   13.00                dragon    Huge  18  172  Legendary  23.0  10.0  21.0
# 10  15.00                dragon    Huge  19  212  Legendary  25.0  10.0  23.0
# 11  14.00                dragon    Huge  18  184  Legendary  23.0  12.0  21.0
# 12  17.00                dragon    Huge  19  256  Legendary  27.0  14.0  25.0
# 13  15.00                dragon    Huge  19  207  Legendary  23.0  12.0  21.0
#
#      int   wis   cha   fly   swim
# 0   11.0  12.0  11.0   fly   None
# 2   18.0  15.0  18.0  swim   None
# 5   10.0  14.0  11.0   NaN    NaN
# 6   14.0  13.0  17.0   fly   swim
# 8   16.0  15.0  19.0   fly   None
# 9   14.0  13.0  17.0   fly   None
# 10  16.0  15.0  19.0   fly   swim
# 11  18.0  15.0  17.0   fly   None
# 12  16.0  15.0  24.0   fly   swim
# 13  18.0  15.0  17.0   fly   swim

# %%
#Replace NaN values
monsters_df[['fly', 'swim']] = monsters_df[['fly', 'swim']].fillna(0)
monsters_df.head()
# Out:
#                  name                                                url
# 0           aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  \
# 2             aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 5             acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...
# 6  adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 8   adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
#
#       cr                  type    size  ac   hp  legendary   str   dex   con
# 0   0.25  humanoid (aarakocra)  Medium  12   13        NaN  10.0  14.0  10.0  \
# 2  10.00            aberration   Large  17  135  Legendary  21.0   9.0  15.0
# 5   0.25   humanoid (any race)  Medium  10    9        NaN  10.0  10.0  10.0
# 6  14.00                dragon    Huge  19  195  Legendary  23.0  14.0  21.0
# 8  16.00                dragon    Huge  19  225  Legendary  25.0  10.0  23.0
#
#     int   wis   cha   fly   swim
# 0  11.0  12.0  11.0   fly      0
# 2  18.0  15.0  18.0  swim      0
# 5  10.0  14.0  11.0     0      0
# 6  14.0  13.0  17.0   fly   swim
# 8  16.0  15.0  19.0   fly      0

# %%
#Drop extra strings in fly+swim columns
monsters_df['fly'] = monsters_df['fly'].replace(['fly'], 'Yes')
monsters_df['fly'] = monsters_df['fly'].replace(['swim', 0], 'No')
monsters_df['swim'] = monsters_df['swim'].replace([' swim'], 'Yes')
monsters_df['swim'] = monsters_df['swim'].replace(['fly', 0], 'No')
monsters_df.head()
# Out:
#                  name                                                url
# 0           aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...  \
# 2             aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 5             acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...
# 6  adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 8   adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
#
#       cr                  type    size  ac   hp  legendary   str   dex   con
# 0   0.25  humanoid (aarakocra)  Medium  12   13        NaN  10.0  14.0  10.0  \
# 2  10.00            aberration   Large  17  135  Legendary  21.0   9.0  15.0
# 5   0.25   humanoid (any race)  Medium  10    9        NaN  10.0  10.0  10.0
# 6  14.00                dragon    Huge  19  195  Legendary  23.0  14.0  21.0
# 8  16.00                dragon    Huge  19  225  Legendary  25.0  10.0  23.0
#
#     int   wis   cha  fly swim
# 0  11.0  12.0  11.0  Yes   No
# 2  18.0  15.0  18.0   No   No
# 5  10.0  14.0  11.0   No   No
# 6  14.0  13.0  17.0  Yes  Yes
# 8  16.0  15.0  19.0  Yes   No

# %%
#Unique values for html dropdown menu
a = monsters_df['type'].unique()
b = monsters_df['size'].unique()
print(sorted(a))
print(sorted(b))
# Out:
# ['aberration', 'beast', 'celestial', 'construct', 'dragon', 'elemental', 'fey', 'fiend', 'fiend (demon)', 'fiend (demon, orc)', 'fiend (demon, shapechanger)', 'fiend (devil)', 'fiend (devil, shapechanger)', 'fiend (shapechanger)', 'fiend (yugoloth)', 'giant', 'giant (stone giant)', 'humanoid (aarakocra)', 'humanoid (any race)', 'humanoid (bullywug)', 'humanoid (dwarf)', 'humanoid (elf)', 'humanoid (gnoll)', 'humanoid (gnome)', 'humanoid (goblinoid)', 'humanoid (grimlock)', 'humanoid (human)', 'humanoid (human, shapechanger)', 'humanoid (kenku)', 'humanoid (kobold)', 'humanoid (kuo-toa)', 'humanoid (lizardfolk)', 'humanoid (merfolk)', 'humanoid (orc)', 'humanoid (sahuagin)', 'humanoid (shapechanger)', 'humanoid (troglodyte)', 'humanoid (yuan-ti)', 'monstrosity', 'monstrosity (shapechanger)', 'monstrosity (shapechanger, yuan-ti)', 'monstrosity (titan)', 'ooze', 'plant', 'swarm of Tiny beasts', 'undead', 'undead (shapechanger)']
# ['Gargantuan', 'Huge', 'Large', 'Medium', 'Small', 'Tiny']

# %%
#Stats for columns
stats = monsters_df[['ac', 'hp', 'str', 'dex', 'con', 'int', 'wis', 'cha']].describe()
print(stats)
# Out:
#                ac          hp         str         dex         con         int
# count  401.000000  401.000000  401.000000  401.000000  401.000000  401.000000  \
# mean    14.109726   81.463840   15.231920   12.745636   15.147132    8.324190
# std      3.165111   98.069768    6.492964    3.183573    4.383012    5.694264
# min      5.000000    1.000000    1.000000    1.000000    8.000000    1.000000
# 25%     12.000000   19.000000   11.000000   10.000000   12.000000    3.000000
# 50%     13.000000   45.000000   16.000000   13.000000   14.000000    8.000000
# 75%     17.000000  112.000000   19.000000   15.000000   17.000000   12.000000
# max     25.000000  676.000000   30.000000   28.000000   30.000000   26.000000
#
#               wis         cha
# count  401.000000  401.000000
# mean    11.820449   10.097257
# std      3.093167    5.696755
# min      2.000000    1.000000
# 25%     10.000000    6.000000
# 50%     12.000000    9.000000
# 75%     13.000000   14.000000
# max     27.000000   30.000000
# Bad pipe message: %s [b"\xcc\x91L,\x9bc\xd2\x1d\xaf\xc1\x8d\x15O\x85\xb7,\xf1\x18 [8\xf8\x98k\xa7\xa5\xfa\xe1O\x91\xcf\x9f-b@{P\xc5\xec\xeea\xfc'\x1a\xf1\xea\xbcd\x0e", b'\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00']
# Bad pipe message: %s [b"\xaa\x99;\x19b\xb68\xca;\x86)\xb6Yu\xa3\xa9\x03\xf3\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0."]
# Bad pipe message: %s [b"\xa2`\x8e\xa1\xe5\xb8\x1f\x8f\x06\xa1\xcf\x04\xf9mb\x85\xd5\x12\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00"]
# Bad pipe message: %s [b"\x977\xc52\x86\xcc\xe4]\x1fv\x96\x87\x03\xfbp\x1a@*\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0", b'\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c']
# Bad pipe message: %s [b'\xa8\xcd\xea\xb8\xd3\xab\n', b"4E'[\xe2\xad\xfe\xf7.\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0"]
# Bad pipe message: %s [b'I\x13~\x8e\xde\xc4\xae$_\xa9\xa5H\x86*\xed~v\xec\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00', b'\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n']
# Bad pipe message: %s [b'\xbe\x85*2\xfeB\xf7:d\x1b$#X%\xbe\xa6OK\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t12', b'0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01']
# Bad pipe message: %s [b'\xf3\xec:P\x17W%\xb6Z\xbd\x80\x87\x93\x83@%\r\xfc\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0', b'\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01']
# Bad pipe message: %s [b"\xae9C\xe5\x9b'\x10\xa0\x9e\x81,\x9a\xa4\xafp\xaeK\xe8\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11"]
# Bad pipe message: %s [b'\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18']
# Bad pipe message: %s [b'1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r']
# Bad pipe message: %s [b'\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08']
# Bad pipe message: %s [b'/\x00\x96']
# Bad pipe message: %s [b'\x06\x04\x01\x05']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']

# %%
#Export final DataFrame
#monsters_df.to_csv("cleaned_dnd_monsters.csv", encoding='utf-8', index=False)
